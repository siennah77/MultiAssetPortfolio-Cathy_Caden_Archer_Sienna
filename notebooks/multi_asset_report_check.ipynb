# %% [markdown]
# #task 1

# %%
import sys
sys.path.append('../src')

from data_loader import load_all
data = load_all('../data')


managers    = data['managers']
benchmarks  = data['benchmarks']
rf          = data['rf']
taa_weights = data['taa_weights']
saa_weights = data['saa_weights']


print("✅ Data loaded")
print(managers.head())
# Out:
# ✅ Data loaded
#               AUS_EQ   INTL_EQ     Bonds  Real_Estate     PE_VC
# Date
# 2016-01-31 -0.036401  0.008283  0.014844    -0.009911 -0.011728
# 2016-02-29  0.046066  0.023213  0.004890     0.033183 -0.031518
# 2016-03-31  0.037724 -0.014881  0.001603     0.031935  0.009824
# 2016-04-30  0.038223  0.010791 -0.001216     0.046568 -0.054742
# 2016-05-31 -0.031612  0.075154  0.020947     0.048911  0.001340

# %%
import sys
sys.path.append('../src')

# %%
from attribution import attribution_summary

test = attribution_summary(
    sleeve_name       = 'AUS_EQ',
    portfolio_returns = managers['AUS_EQ'],
    benchmark_returns = benchmarks['AUS_EQ'],
    taa_weights       = taa_weights['AUS_EQ'],
    saa_weights       = saa_weights['AUS_EQ'],
)

print(test)
# Out:
# {'Sleeve': 'AUS_EQ', 'Allocation Effect': <bound method Series.sum of Date
# 2016-01-31    0.001245
# 2016-02-29   -0.002070
# 2016-03-31   -0.001665
# 2016-04-30   -0.001205
# 2016-05-31    0.001350
#                 ...
# 2025-08-31    0.000695
# 2025-09-30   -0.000185
# 2025-10-31    0.001510
# 2025-11-30   -0.000580
# 2025-12-31   -0.000890
# Name: AUS_EQ, Length: 120, dtype: float64>, 'Selection Effect': <bound method Series.sum of Date
# 2016-01-31   -0.004600
# 2016-02-29    0.001867
# 2016-03-31    0.001770
# 2016-04-30    0.005649
# 2016-05-31   -0.001845
#                 ...
# 2025-08-31    0.000927
# 2025-09-30    0.004671
# 2025-10-31   -0.004725
# 2025-11-30   -0.003357
# 2025-12-31    0.004514
# Name: AUS_EQ, Length: 120, dtype: float64>, 'Total': <bound method Series.sum of Date
# 2016-01-31   -0.003355
# 2016-02-29   -0.000203
# 2016-03-31    0.000105
# 2016-04-30    0.004444
# 2016-05-31   -0.000495
#                 ...
# 2025-08-31    0.001622
# 2025-09-30    0.004486
# 2025-10-31   -0.003215
# 2025-11-30   -0.003937
# 2025-12-31    0.003624
# Name: AUS_EQ, Length: 120, dtype: float64>}

# %%
from attribution import all_sleeves_attribution

sleeves = ['AUS_EQ', 'INTL_EQ', 'Bonds', 'Real_Estate', 'PE_VC']

summary = all_sleeves_attribution(
    manager_returns   = managers,
    benchmark_returns = benchmarks,
    sleeves           = sleeves,
    taa_weights       = taa_weights,
    saa_weights       = saa_weights,
)

print(summary)
# Out:
#                                              Allocation Effect  \
# Sleeve
# AUS_EQ       <bound method Series.sum of Date\n2016-01-31  ...
# INTL_EQ      <bound method Series.sum of Date\n2016-01-31  ...
# Bonds        <bound method Series.sum of Date\n2016-01-31  ...
# Real_Estate  <bound method Series.sum of Date\n2016-01-31  ...
# PE_VC        <bound method Series.sum of Date\n2016-01-31  ...
#
#                                               Selection Effect  \
# Sleeve
# AUS_EQ       <bound method Series.sum of Date\n2016-01-31  ...
# INTL_EQ      <bound method Series.sum of Date\n2016-01-31  ...
# Bonds        <bound method Series.sum of Date\n2016-01-31  ...
# Real_Estate  <bound method Series.sum of Date\n2016-01-31  ...
# PE_VC        <bound method Series.sum of Date\n2016-01-31  ...
#
#                                                          Total
# Sleeve
# AUS_EQ       <bound method Series.sum of Date\n2016-01-31  ...
# INTL_EQ      <bound method Series.sum of Date\n2016-01-31  ...
# Bonds        <bound method Series.sum of Date\n2016-01-31  ...
# Real_Estate  <bound method Series.sum of Date\n2016-01-31  ...
# PE_VC        <bound method Series.sum of Date\n2016-01-31  ...
